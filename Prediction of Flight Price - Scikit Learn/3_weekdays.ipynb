# %%
# test_10000.csv


import numpy as np
import pandas as pd
import datetime as dt
# import matplotlib.pyplot as plt
#[]
cols = ['ORIG','DEST','SALE_STR_DATE','TRAVEL_STR_DATE','SEASON_STR_DATE','DOW','MIN_STAY_UNIT','MIN_STAY_VAL','MAX_STAY_UNIT',
        'MAX_STAY_VAL','AP_UNIT','AP_VALUE','RBD','FAREAMT_BC']
res_col = ['']
path = 'test_10000_convered_places.csv'
df = pd.read_csv(path, usecols=cols)

# %%
#add 7 columns day_1-day_7
from pandas import Series as series

for i in range(1,8):
    df['DAY_'+ str(i)] = series(np.zeros(df['DOW'].size, dtype=int), index=df.index)

# %%
df.head()
# Out:
#    ORIG  DEST  SALE_STR_DATE  TRAVEL_STR_DATE  SEASON_STR_DATE      DOW  \
# 0    13     7             59               59              228  71234.0
# 1    13    17            144              144              195   4567.0
# 2    63    10             59               59              242  71234.0
# 3    52    83             59               59              186  71234.0
# 4    82    15             59               59              187  71234.0
#
#   MIN_STAY_UNIT MIN_STAY_VAL MAX_STAY_UNIT  MAX_STAY_VAL  ...    AP_UNIT  \
# 0             1          SUN             M             6  ...        NaN
# 1           NaN          NaN             M            12  ...        NaN
# 2           NaN          NaN             M            12  ...        NaN
# 3             1          SUN             M             6  ...        NaN
# 4             1          SUN             M             6  ...        NaN
#
#   AP_VALUE  RBD day_1  day_2  day_3  day_4  day_5  day_6  day_7
# ...

# %%
import math
def strip_to_days():
        for i in range(df['DOW'].size):
            cur = df.loc[i,'DOW']
            if math.isnan(cur):
                print("found NaN")
                continue
            days = str(int(cur))
            days = [x for x in days]
            for x in days:
                df.loc[i, 'DAY_'+x] = 1
     
strip_to_days()
# Out:
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# found NaN
# ...

# %%
df.head()
# Out:
#    ORIG  DEST  SALE_STR_DATE  TRAVEL_STR_DATE  SEASON_STR_DATE      DOW  \
# 0    15    36             59               59              228  71234.0
# 1    15    78            144              144              195   4567.0
# 2    38     2             59               59              242  71234.0
# 3    37    62             59               59              186  71234.0
# 4    42    52             59               59              187  71234.0
#
#   MIN_STAY_UNIT MIN_STAY_VAL MAX_STAY_UNIT  MAX_STAY_VAL  ...    AP_UNIT  \
# 0             1          SUN             M             6  ...        NaN
# 1           NaN          NaN             M            12  ...        NaN
# 2           NaN          NaN             M            12  ...        NaN
# 3             1          SUN             M             6  ...        NaN
# 4             1          SUN             M             6  ...        NaN
#
#   AP_VALUE  RBD DAY_1  DAY_2  DAY_3  DAY_4  DAY_5  DAY_6  DAY_7
# ...

# %%
df.to_csv('test_10000_convered_weekdays.csv')
